# %%
import sys
import nltk
import numpy as np
import pandas as pd
from copy import deepcopy
import gensim
from gensim.models import Word2Vec
from gensim.models import Phrases
import re
from nltk.corpus import stopwords
from scipy.special import expit as sigmoid

# %%
# 1 Fail
# 2 Success
# 8 Commons
# 9 Lords
#18 failed commons


nltk.download('stopwords')

 

def cleanFilesInFolder(startSession, endSession, house_and_status=[18, 19, 28, 29]):
    for code in house_and_status:
        file_name = f"CSVFilesMLP/{code}_{startSession} to {endSession}.csv"
        try:
            df = pd.read_csv(file_name)
            long_titles = df['Long Title'].astype(str)  
            output_file_name = f"cleanedText/{code}_{startSession} to {endSession}.txt"
            
            with open(output_file_name, "w", encoding="utf-8") as file:
                for title in long_titles:
                    modified_title = title.replace('A Bill to', '').replace('; and for connected purposes', '') 
                    modified_title = modified_title.lower()    
                    file.write(modified_title)
        except UnicodeEncodeError as e:
            print(f"Encoding error in file {file_name}: {e}")
        except Exception as e:
            print(f"An error occurred while processing {file_name}: {e}")



def splitSentences(text):
    
    sentences = re.split(r'\.\s+', text)
    stop_words = set(stopwords.words('english'))
    
    sentences = [sentence.strip() for sentence in sentences if sentence.strip()]
    filtered_sentences = []
    for sentence in sentences:
        words = sentence.split()
        filtered_words = [word for word in words if word.lower() not in stop_words]
        filtered_sentences.append(filtered_words)
        
    return filtered_sentences


def splitDocument(house_and_status = [18,19,28,29]):
    for code in house_and_status: 
        file_name = f"cleanedText/{code}/Training/training_text{code}.txt"
        try:
            with open(file_name, 'r', encoding="utf-8") as file:
                for line in file:
                    yield splitSentences(line)
            print(f"Read File{file_name}")
        except UnicodeDecodeError as e:
            print(f"Unicode decode error")

def splitDocumentAll(startSession, endSession, house_and_status = [18,19,28,29]):
    for code in house_and_status: 
        file_name = f"cleanedText/{code}_{startSession} to {endSession}.txt"
        try:
            with open(file_name, 'r', encoding="utf-8") as file:
                for line in file:
                    yield splitSentences(line)
            print(f"Read File{file_name}")
        except UnicodeDecodeError as e:
            print(f"Unicode decode error")
# returns a list of lists . List each sentnece, and inside there is a list of words for each sentence

def trainW2V(key, T=50):
    sentences = categorizedBillSentences[key]
    for epoch in range(T):
        print(f"{epoch}", end="")
        np.random.shuffle(sentences)
        models[key].train(sentences, total_examples=len(sentences), epochs=1)
        models[key].alpha *= 0.9
        models[key].min_alpha = models[key].alpha
    print(".")
    


def nearby(word, g):
    print(word)
    print(f"{g}:", end=" ")
    try:
        if word in models[g].wv.key_to_index:  
            for (w, v) in models[g].wv.most_similar([word]):
                print(w, end=" ")
        else:
            print("Word not in vocabulary!", end=" ")
    except Exception as e:
        print(f"Error: {e}")
    print("\n")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ander\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# input (sentence: list of words, model: gensim model, window: window= windowSize of word2vec, 
#debug: print intermediate calculations for debugging)

def score_sentence(sentence, model, window=5, debug=False):
    log_prob = 0.0 # total log prob for the sentence
    sentence_length = len(sentence)
    word_pair_probs = []  

    # Code for equation 1 
    for index, center_word in enumerate(sentence):
        if center_word not in model.wv:
            if debug:
                print(f"Center word '{center_word}' not in vocabulary.")
            continue
        center_vector = model.wv[center_word]

        start = max(0, index - window)
        end = min(sentence_length, index + window + 1)

        for j in range(start, end):
            if j == index:
                continue
            context_word = sentence[j]
            if context_word not in model.wv:
                if debug:
                    print(f"Context word '{context_word}' not in vocabulary.")
                continue
            context_vector = model.wv[context_word]

            dot_product = np.dot(center_vector, context_vector)
            prob = sigmoid(dot_product)

            word_pair_probs.append((center_word, context_word, prob))

            log_prob += np.log(prob + 1e-10)

    if debug:
        print("\n--- Word Pair Probabilities ---")
        for center, context, prob in word_pair_probs:
            print(f"p({context} | {center}) = {prob:.6f}")

    return log_prob




# Score an entire document (S sentences) under all models (Equation 2)
# input (sentencces:  a list of sentences ,models: the dictionary of models, window: the window size for score sentences)
# outpur: a sentences x categories (failed , succesful ....) with eahc sentence score according to score_sentence

def score_document(sentences, models, window=5):
    """
    Compute the score x category matrix of sentence scores for a document.
    
    sentences: list of sentences, each sentence is a list of words
    models: dict of {category: Word2Vec model}
    """
    S = len(sentences)
    C = len(models)
    
    sentence_scores = np.zeros((S, C))
    
    for s_idx, sentence in enumerate(sentences):
        for c_idx, (category, model) in enumerate(models.items()):
            sentence_scores[s_idx, c_idx] = score_sentence(sentence, model, window)
    
    return sentence_scores



# calculate document probabilities (Equation 5)

# input: the sxc array
# output: a 1x cateories array with the average score for all sentences in document 
def document_probabilities(sentence_scores):

    return sentence_scores.mean(axis=0)



# compute class probabilities ( Equation 3)

# input:  the array from document_probabilities
#ouput: normalized probabilities after bayes rule is applied #todo: change the priors to correspond to each class 
def class_probabilities(log_doc_probs):

    num_classes = len(log_doc_probs)
    doc_probs = np.exp(log_doc_probs - np.max(log_doc_probs)) 
    
    priors = np.ones(num_classes) / num_classes

    numerator = doc_probs * priors
    denominator = np.sum(numerator)
    probs = numerator / denominator
    
    return probs



# classify the document (Equation 6)
# checks which of the numbers in the 1d array from document probabilities (the average across the classes ) is biggest and returns the index and array (for debuging) 
 
def classify_document(sentence_scores):
    doc_probs = document_probabilities(sentence_scores)
    class_probs = class_probabilities(doc_probs)
    predicted_class_idx = np.argmax(class_probs)
    return predicted_class_idx, class_probs

# %%
#Split Into validation and 
def splitIntoSets(code):
    csv_path = f"C:\\Users\\ander\\Downloads\\MLP\\CSVFilesWithTitleScores\\{code}_17 to 39_withTitleScores.csv"

    df = pd.read_csv(csv_path)

    total_rows = len(df)
    testingSetSize = round(0.1 * total_rows)
    remainingSize = total_rows - testingSetSize


    testingSet = df.iloc[:testingSetSize]['Bill Id'].tolist()


    remaining_df = df.iloc[testingSetSize:].sample(frac=1, random_state=42) 
    
    validationSet = remaining_df.iloc[:testingSetSize]['Bill Id'].tolist()


    trainingSet = remaining_df.iloc[testingSetSize:]['Bill Id'].tolist()
    
    return trainingSet, testingSet, validationSet

remaining = [28, 29, 18, 19]

for code in remaining :
    trainingIndexes, testingIndexes, validationIndexes = splitIntoSets(code)
    df = pd.read_csv(f"C:\\Users\\ander\\Downloads\\MLP\\CSVFilesWithTitleScores\\{code}_17 to 39_withTitleScores.csv")


    df_training = df[df['Bill Id'].isin(trainingIndexes)]
    df_testing = df[df['Bill Id'].isin(testingIndexes)]
    df_validation = df[df['Bill Id'].isin(validationIndexes)]
    df_training.to_csv(f"C:\\Users\\ander\\Downloads\\MLP\\CSVFilesWithTitleScores\\{code}\\Training\\{code}_training.csv", index=False)
    df_testing.to_csv(f"C:\\Users\\ander\\Downloads\\MLP\\CSVFilesWithTitleScores\\{code}\\Testing\\{code}_testing.csv", index=False)
    df_validation.to_csv(f"C:\\Users\\ander\\Downloads\\MLP\\CSVFilesWithTitleScores\\{code}\\Validation\\{code}_validation.csv", index=False)

# %%
# Go from CSV files to 4 trained word2Vec models , 1 per category

startSession = 17
endSession= 39

# Convert from csv file to text file with just the long titles of the bills for all 4 files of te start-end session range
cleanFilesInFolder(startSession, endSession)

#combine sentences from all 4 files into 1 list of lists. Each sentence a list of words 
allSentences = [sentence for listOfSentneces in splitDocumentAll(startSession, endSession) for sentence in listOfSentneces]

print("Sentences retreived")
print(len(allSentences))


# the catgeories are also used in scoring, the index for categories relates to this  
houseDictionary = {'FailedCommons': [18], 'FailedLords': [19], "SuccesCommons": [28], "SuccessLords":[29]}
[g for g in houseDictionary]



# populate a dictionary: key: category of bill, value: list of lists with sentences from bills of that category(FailedCommons, etc)
categorizedBillSentences = {key: [sentence for listOfSentneces in splitDocument(startSession, endSession, houseDictionary[key]) for sentence in listOfSentneces] for key in houseDictionary}

# creates series with how many sentnces for each catgory(debugging)
numberBills = pd.Series({key: len(categorizedBillSentences[key]) for key in houseDictionary}, dtype="float64" )

print("Sentences per category")
print(f"Sentences in FailedCommons {numberBills[0]}")
print(f"Sentences in FailedCommons {numberBills[1]}")
print(f"Sentences in FailedCommons {numberBills[2]}")
print(f"Sentences in FailedCommons {numberBills[3]}")


# populate houseDictionary with bills of appropaite category as lists of lists
for key in houseDictionary:
    for i in range(len(categorizedBillSentences[key])):
        categorizedBillSentences[key][i] = [word for word in categorizedBillSentences[key][i]]


#creates a dictionary of word2vec models initialized with the vocabulary of all sentences         


models = { }


for key in houseDictionary:
    models[key] = Word2Vec(allSentences, workers=4, hs=1, negative=0)
    models[key].build_vocab(allSentences) 
    
    

# trains each of the initialized models only with text from each specific category. 4 models trained with different bill text
for key in houseDictionary:
    print(key, end=":")
    trainW2V(key)


print(models.keys())
# Out:
# Read FilecleanedText/18_17 to 39.txt
# Read FilecleanedText/19_17 to 39.txt
# Read FilecleanedText/28_17 to 39.txt
# Read FilecleanedText/29_17 to 39.txt
# Sentences retreived
# 2830
# Read FilecleanedText/18_17 to 39.txt
# Read FilecleanedText/19_17 to 39.txt
# Read FilecleanedText/28_17 to 39.txt
# Read FilecleanedText/29_17 to 39.txt
# Sentences per category
# Sentences in FailedCommons 2019.0
# Sentences in FailedCommons 282.0
# Sentences in FailedCommons 448.0
# Sentences in FailedCommons 81.0
# FailedCommons:012345678910111213141516171819202122232425262728293031323334353637383940414243444546474849.
# FailedLords:012345678910111213141516171819202122232425262728293031323334353637383940414243444546474849.
# SuccesCommons:012345678910111213141516171819202122232425262728293031323334353637383940414243444546474849.
# SuccessLords:012345678910111213141516171819202122232425262728293031323334353637383940414243444546474849.
# dict_keys(['FailedCommons', 'FailedLords', 'SuccesCommons', 'SuccessLords'])

# %%
#Score sentences from the next three sessions(compared to the sessions the models were trained with) and evaluate how accurate the models are 

sentences = [
    "A Bill to require the Secretary of State to promote and secure youth services and provision of a requisite standard; to impose a duty on local authorities to provide youth services and establish local youth service partnerships with youth participation; and for connected purposes.",
    
    "A Bill to Authorise the use of resources for the year ending with 31 March 2020; to authorise both the issue of sums out of the Consolidated Fund and the application of income for that year; and to appropriate the supply authorised for that year by this Act and by the Supply and Appropriation (Anticipation and Adjustments) Act 2019.",
    
    "A Bill to make provision for unaccompanied asylum seeking children to receive legal advice and for extending the deadline for an unaccompanied asylum seeking child to appeal an asylum decision",
    
    "To confer powers upon New Southgate Cemetery and Crematorium Limited and the National Spiritual Assembly of the BahÃ¡'is of the United Kingdom to extinguish rights of burial and disturb human remains in respect of New Southgate Cemetery for the purpose of increasing the space for interments; and for connected purposes."
]



categories = list(models.keys())

for i, sentence_text in enumerate(sentences, 1):
    document = splitSentences(sentence_text)  
    sentence_scores = score_document(document, models, window=5)
    doc_probs = document_probabilities(sentence_scores)
    probs = class_probabilities(doc_probs)
    predicted_idx, doc_probs = classify_document(sentence_scores)

    print(f"\nSentence {i}:")
    print(f"Predicted class: {categories[predicted_idx]}")
    print(f"Document probabilities: {doc_probs}")
    print(f"Class probabilities: {probs}")
# Out:
# Sentence 1:
# Predicted class: FailedCommons
# Document probabilities: [9.26957648e-01 3.66640828e-23 7.30423519e-02 4.65472102e-13]
# Class probabilities: [9.26957648e-01 3.66640828e-23 7.30423519e-02 4.65472102e-13]
#
# Sentence 2:
# Predicted class: SuccesCommons
# Document probabilities: [3.62247042e-39 4.47187653e-22 1.00000000e+00 1.33229280e-22]
# Class probabilities: [3.62247042e-39 4.47187653e-22 1.00000000e+00 1.33229280e-22]
#
# Sentence 3:
# Predicted class: FailedLords
# Document probabilities: [2.41413224e-86 1.00000000e+00 6.64246535e-37 8.61886923e-37]
# Class probabilities: [2.41413224e-86 1.00000000e+00 6.64246535e-37 8.61886923e-37]
#
# Sentence 4:
# Predicted class: SuccessLords
# Document probabilities: [3.35402341e-19 2.83840187e-15 5.79228968e-18 1.00000000e+00]
# Class probabilities: [3.35402341e-19 2.83840187e-15 5.79228968e-18 1.00000000e+00]

# %%
#Prepare data to test models. Split csv files into list of long titles per category


#Split a file into complete sentences. Files for success commons 28-30

def scoreSentences(listOfSentences, modelsList, predictedCategory):
    success= 0
    fail =0
    
    categories = list(modelsList.keys())
    
    for i, sentence_text in enumerate(listOfSentences, 1):
        document = splitSentences(sentence_text)
        sentence_scores = score_document(document, modelsList, window=5)
        doc_probs = document_probabilities(sentence_scores)
        probs = class_probabilities(doc_probs)
        predicted_idx, doc_probs = classify_document(sentence_scores)
        
        print(f" Predicting Sentence {document}")
        print(f"\nSentence {i}:")
        print(f"Predicted class: {categories[predicted_idx]}")
        print(f"Document probabilities: {doc_probs}")
        print(f"Class probabilities: {probs}")
        
        if (categories[predicted_idx] == predictedCategory):
            success = success + 1
        else:
            fail = fail + 1
    total = fail + success
    if total > 0:
        accuracy = success / total
        print(f"Correct Prediction: {accuracy}")
    else:
        print("Error in predicition.")


startSessionTest = 35
endSessionTest = 37


def splitSentencesForTest(text):
    
    sentences = re.split(r'\.\s+', text)    
    return sentences


def splitDocumentTest(startSession, endSession, house_and_status):
    for code in house_and_status: 
        file_name = f"cleanedText/{code}_{startSession} to {endSession}.txt"
        try:
            with open(file_name, 'r', encoding="utf-8") as file:
                for line in file:
                    sentences = splitSentencesForTest(line.strip())
                    for sentence in sentences:
                        yield sentence 
            print(f"Read File{file_name}")
        except UnicodeDecodeError as e:
            print(f"Unicode decode error")



codes= [18,19,28,19]


testDictionary = {'FailedCommons': [18], 'FailedLords': [19], "SuccesCommons": [28], "SuccessLords":[29]}


for key, codes in testDictionary.items():
    testDictionary[key] = [sentence for sentence in splitDocumentTest(startSessionTest, endSessionTest, house_and_status=codes)]

#for key, sentences in testDictionary.items():
 #   print(f"{key}: {sentences[:5]}")
    
      


for key, code in testDictionary.items():
    testSentences = testDictionary[key]
    
    print (f" Number of sentences for {key} is {len(testSentences)}")
    print(f"The accuracy for {key} is ") 
    scoreSentences(testSentences, models, key)
    

# save the models 
from gensim.models import Word2Vec


for key, model in models.items():
    filename = f"{key}_word2vec_titles.model"
    model.save(filename)
    print(f"Model for {key} saved as {filename}")

    
# dict_keys(['FailedCommons', 'FailedLords', 'SuccesCommons', 'SuccessLords'])
# Out:
# Read FilecleanedText/18_35 to 37.txt
# Read FilecleanedText/19_35 to 37.txt
# Read FilecleanedText/28_35 to 37.txt
# Read FilecleanedText/29_35 to 37.txt
#  Number of sentences for FailedCommons is 617
# The accuracy for FailedCommons is
#  Predicting Sentence [['amend', 'crown', 'estate', 'act', '1961', 'increase', 'maximum', 'term', 'lease', 'may', 'granted', 'zoological', 'society', 'london', 'respect', 'land', 'regent’s', 'park']]
#
# Sentence 1:
# Predicted class: FailedLords
# Document probabilities: [1.45036321e-04 9.98661080e-01 1.04588453e-03 1.47999352e-04]
# Class probabilities: [1.45036321e-04 9.98661080e-01 1.04588453e-03 1.47999352e-04]
#  Predicting Sentence [['amend', 'working', 'time', 'regulations', '1998', 'reduce', 'maximum', 'working', 'week', '48', 'hours', 'per', 'week', '32', 'hours', 'per', 'week', 'provide', 'overtime', 'pay']]
#
# Sentence 2:
# Predicted class: FailedCommons
# Document probabilities: [9.99999359e-01 1.95687949e-08 6.20936403e-07 2.28532739e-10]
# Class probabilities: [9.99999359e-01 1.95687949e-08 6.20936403e-07 2.28532739e-10]
#  Predicting Sentence [['make', 'provision', 'workers’', 'rights;', 'amend', 'definition', 'worker']]
#
# Sentence 3:
# Predicted class: FailedCommons
# Document probabilities: [9.99904715e-01 1.27321471e-05 3.63329591e-05 4.62200999e-05]
# Class probabilities: [9.99904715e-01 1.27321471e-05 3.63329591e-05 4.62200999e-05]
#  Predicting Sentence [['make', 'provision', 'monitoring', 'water', 'quality;', 'set', 'target', 'reduction', 'sewage', 'discharges;', 'provide', 'financial', 'penalties', 'relation', 'sewage', 'discharges', 'breaches', 'monitoring', 'requirements;', 'require', 'secretary', 'state', 'publish', 'strategy', 'reduction', 'sewage', 'discharges', 'storm', 'overflows,', 'including', 'economic', 'impact', 'assessment']]
#
# Sentence 4:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 3.54346720e-21 2.02256316e-40 4.13145544e-17]
# Class probabilities: [1.00000000e+00 3.54346720e-21 2.02256316e-40 4.13145544e-17]
#  Predicting Sentence [['establish', 'independent', 'public', 'inquiry', 'administration', 'war', 'pension', 'scheme', 'armed', 'forces', 'compensation', 'scheme', 'veterans', 'uk']]
#
# Sentence 5:
# Predicted class: SuccessLords
# Document probabilities: [1.59724589e-22 5.57965994e-30 8.51126689e-04 9.99148873e-01]
# Class probabilities: [1.59724589e-22 5.57965994e-30 8.51126689e-04 9.99148873e-01]
#  Predicting Sentence [['prohibit', 'persons', 'registered', 'vote', 'parliamentary', 'elections', 'one', 'address']]
#
# Sentence 6:
# Predicted class: FailedLords
# Document probabilities: [5.13166617e-04 9.97310190e-01 9.74960656e-06 2.16689394e-03]
# Class probabilities: [5.13166617e-04 9.97310190e-01 9.74960656e-06 2.16689394e-03]
#  Predicting Sentence [['provide', 'offences', 'genocide,', 'crimes', 'humanity', 'war', 'crimes', 'may', 'tried', 'united', 'kingdom', 'regardless', 'nationality', 'residence', 'offender']]
#
# Sentence 7:
# Predicted class: FailedCommons
# Document probabilities: [9.99058396e-01 1.59020454e-05 3.78167624e-12 9.25701536e-04]
# Class probabilities: [9.99058396e-01 1.59020454e-05 3.78167624e-12 9.25701536e-04]
#  Predicting Sentence [['amend', 'welfare', 'reform', 'act', '2012', 'provide', 'universal', 'credit', 'claimant', 'may', 'sanctioned', 'refusing', 'work', 'zero', 'hours', 'contract']]
#
# Sentence 8:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 2.54044263e-24 1.87126428e-23 5.22637598e-30]
# Class probabilities: [1.00000000e+00 2.54044263e-24 1.87126428e-23 5.22637598e-30]
#  Predicting Sentence [['require', 'secretary', 'state', 'report', 'parliament', 'merits', 'repealing', 'provisions', 'welfare', 'reform', 'act', '2012', 'provide', 'persons', 'paid', 'reduced', 'rates', 'housing', 'benefit', 'universal', 'credit', 'accommodation', 'deemed', 'under-occupied']]
#
# Sentence 9:
# Predicted class: SuccessLords
# Document probabilities: [2.66290713e-19 5.91444623e-03 2.97013508e-04 9.93788540e-01]
# Class probabilities: [2.66290713e-19 5.91444623e-03 2.97013508e-04 9.93788540e-01]
#  Predicting Sentence [['set', 'limits', 'use', 'toxic', 'chemicals', 'manufacture', 'tyres']]
#
# Sentence 10:
# Predicted class: FailedCommons
# Document probabilities: [0.61081457 0.26967701 0.01373884 0.10576958]
# Class probabilities: [0.61081457 0.26967701 0.01373884 0.10576958]
#  Predicting Sentence [['provide', 'implementation', 'united', 'kingdom’s', 'free', 'trade', 'agreements', 'australia', 'new', 'zealand', 'subject', 'approval', 'resolution', 'house', 'parliament']]
#
# Sentence 11:
# Predicted class: SuccessLords
# Document probabilities: [6.72277489e-09 6.48221106e-06 8.22540529e-07 9.99992689e-01]
# Class probabilities: [6.72277489e-09 6.48221106e-06 8.22540529e-07 9.99992689e-01]
#  Predicting Sentence [['establish', 'new', 'model', 'company', 'structure', 'thames', 'water,', 'called', 'public', 'benefit', 'corporation;', 'require', 'public', 'benefit', 'corporation', 'consider', 'public', 'policy', 'benefits,', 'including', 'reducing', 'leaks', 'sewage', 'dumping,', 'well', 'returns', 'shareholders;', 'limit', 'payment', 'dividends', 'plan', 'place', 'cut', 'corporation’s', 'debt;', 'require', 'membership', 'corporation’s', 'board', 'include', 'representatives', 'local', 'environment', 'groups']]
#
# Sentence 12:
# Predicted class: FailedLords
# Document probabilities: [3.02669569e-33 9.98864493e-01 3.15359083e-08 1.13547537e-03]
# Class probabilities: [3.02669569e-33 9.98864493e-01 3.15359083e-08 1.13547537e-03]
#  Predicting Sentence [['require', 'utility', 'companies', 'provide', 'financial', 'support', 'customers', 'terminal', 'illness;', 'make', 'provision', 'employment', 'rights', 'people', 'terminal', 'illness']]
#
# Sentence 13:
# Predicted class: SuccesCommons
# Document probabilities: [1.49425120e-04 2.78783680e-04 7.30127661e-01 2.69444130e-01]
# Class probabilities: [1.49425120e-04 2.78783680e-04 7.30127661e-01 2.69444130e-01]
#  Predicting Sentence [['make', 'provision', 'mandatory', 'local', 'consultation', 'relation', 'installation', 'telecommunications', 'infrastructure', 'residential', 'areas']]
#
# Sentence 14:
# Predicted class: FailedCommons
# Document probabilities: [9.99999997e-01 3.48837329e-13 3.02614826e-10 2.67103871e-09]
# Class probabilities: [9.99999997e-01 3.48837329e-13 3.02614826e-10 2.67103871e-09]
#  Predicting Sentence [['place', 'duty', 'secretary', 'state', 'promote', 'safety', 'wellbeing', 'teenagers;', 'make', 'provision', 'prevent', 'crime', 'teenagers']]
#
# Sentence 15:
# Predicted class: FailedLords
# Document probabilities: [3.08371492e-06 9.99056583e-01 2.50265461e-07 9.40082655e-04]
# Class probabilities: [3.08371492e-06 9.99056583e-01 2.50265461e-07 9.40082655e-04]
#  Predicting Sentence [['establish', 'commission', 'assess', 'differential', 'impact', 'tax', 'system', 'uk', 'different', 'groups', 'people;', 'require', 'commission', 'make', 'recommendations', 'reform', 'tax', 'system']]
#
# Sentence 16:
# Predicted class: SuccesCommons
# Document probabilities: [2.69341293e-30 3.99062530e-05 8.30019933e-01 1.69940161e-01]
# Class probabilities: [2.69341293e-30 3.99062530e-05 8.30019933e-01 1.69940161e-01]
#  Predicting Sentence [['exempt', 'sun', 'protection', 'products', 'vat']]
#
# Sentence 17:
# Predicted class: SuccessLords
# Document probabilities: [0.00258496 0.06095309 0.09321324 0.84324871]
# Class probabilities: [0.00258496 0.06095309 0.09321324 0.84324871]
#  Predicting Sentence [['make', 'provision', 'law', 'relation', 'administering', 'attempting', 'administer', 'drugs,', 'alcohol', 'substance', 'person', 'without', 'consent,', 'whether', 'intent', 'cause', 'harm']]
#
# Sentence 18:
# Predicted class: FailedLords
# Document probabilities: [0.22477748 0.76572023 0.00671824 0.00278405]
# Class probabilities: [0.22477748 0.76572023 0.00671824 0.00278405]
#  Predicting Sentence [['require', 'secretary', 'state', 'publish', 'annual', 'calculations', 'benefit', 'tax', 'credit', 'rates', 'would', 'required', 'representative', 'household', 'afford', 'buy', 'meals', 'accordance', 'eatwell', 'guide', 'eating', 'healthily']]
#
# Sentence 19:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 2.71702066e-18 6.03651718e-29 7.87167692e-20]
# Class probabilities: [1.00000000e+00 2.71702066e-18 6.03651718e-29 7.87167692e-20]
#  Predicting Sentence [['give', 'local', 'authorities', 'power', 'require', 'licences', 'conversion', 'domestic', 'properties', 'short-term', 'holiday-let', 'accommodation;', 'give', 'local', 'authorities', 'power', 'issue', 'fines', 'remove', 'licences', 'safety,', 'noise', 'nuisance', 'conditions', 'met;', 'make', 'provision', 'banning', 'licensing', 'properties', 'defined', 'geographical', 'areas;', 'give', 'local', 'authorities', 'power', 'vary', 'rates', 'local', 'taxes', 'relation', 'properties;', 'give', 'local', 'authorities', 'power', 'restrict', 'number', 'days', 'per', 'year', 'properties', 'let']]
#
# Sentence 20:
# Predicted class: SuccessLords
# Document probabilities: [1.43389500e-06 1.49456192e-32 3.13732615e-38 9.99998566e-01]
# Class probabilities: [1.43389500e-06 1.49456192e-32 3.13732615e-38 9.99998566e-01]
#  Predicting Sentence [['make', 'provision', 'shared', 'parental', 'leave', 'pay', 'certain', 'cases', 'one', 'child’s', 'parents', 'died']]
#
# Sentence 21:
# Predicted class: SuccessLords
# Document probabilities: [8.26910875e-03 4.78606588e-02 1.45790338e-08 9.43870218e-01]
# Class probabilities: [8.26910875e-03 4.78606588e-02 1.45790338e-08 9.43870218e-01]
#  Predicting Sentence [['amend', 'sentencing', 'code', 'provide', 'minimum', 'sentence', 'cases', 'manslaughter', 'sexually-motivated']]
#
# Sentence 22:
# Predicted class: FailedCommons
# Document probabilities: [9.93688584e-01 1.19307442e-04 2.75562884e-03 3.43647974e-03]
# Class probabilities: [9.93688584e-01 1.19307442e-04 2.75562884e-03 3.43647974e-03]
#  Predicting Sentence [['prohibit', 'person', 'subject', 'notification', 'requirements', 'part', '2', 'sexual', 'offences', 'act', '2003', 'changing', 'name']]
#
# Sentence 23:
# Predicted class: SuccessLords
# Document probabilities: [8.83829953e-07 5.36561231e-07 6.31904941e-08 9.99998516e-01]
# Class probabilities: [8.83829953e-07 5.36561231e-07 6.31904941e-08 9.99998516e-01]
#  Predicting Sentence [['require', 'secretary', 'state', 'lay', 'parliament', 'proposals', 'seizure', 'russian', 'state', 'assets', 'provide', 'support', 'ukraine']]
#
# Sentence 24:
# Predicted class: SuccessLords
# Document probabilities: [1.67604548e-04 9.69123369e-04 1.41062943e-15 9.98863272e-01]
# Class probabilities: [1.67604548e-04 9.69123369e-04 1.41062943e-15 9.98863272e-01]
#  Predicting Sentence [['make', 'offence', 'driving', 'riding', 'motor', 'vehicle', 'road', 'without', 'seat', 'belt', 'endorsable', 'offence']]
#
# Sentence 25:
# Predicted class: FailedCommons
# Document probabilities: [9.99564881e-01 4.18695109e-07 4.32446083e-04 2.25432515e-06]
# Class probabilities: [9.99564881e-01 4.18695109e-07 4.32446083e-04 2.25432515e-06]
#  Predicting Sentence [['amend', 'scotland', 'act', '1998', 'transfer', 'power', 'legislate', 'scottish', 'independence', 'referendum', 'scottish', 'parliament;', 'provide', 'power', 'may', 'exercised', 'scottish', 'public', 'demonstrated', 'support', 'holding', 'referendum;', 'provide', 'referendum', 'may', 'held', 'sooner', 'seven', 'years', 'previous', 'referendum']]
#
# Sentence 26:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 3.15478342e-46 1.37241743e-19 1.62602184e-22]
# Class probabilities: [1.00000000e+00 3.15478342e-46 1.37241743e-19 1.62602184e-22]
#  Predicting Sentence [['enable', 'clergy', 'church', 'england', 'conduct', 'sex', 'marriages', 'church', 'england', 'premises', 'certain', 'circumstances']]
#
# Sentence 27:
# Predicted class: SuccesCommons
# Document probabilities: [9.01275862e-03 1.02184475e-06 9.90986199e-01 2.08354498e-08]
# Class probabilities: [9.01275862e-03 1.02184475e-06 9.90986199e-01 2.08354498e-08]
#  Predicting Sentence [['make', 'provision', 'sale', 'retail', 'tobacco', 'related', 'goods']]
#
# Sentence 28:
# Predicted class: FailedCommons
# Document probabilities: [9.25739713e-01 1.00937182e-08 8.50758745e-07 7.42594263e-02]
# Class probabilities: [9.25739713e-01 1.00937182e-08 8.50758745e-07 7.42594263e-02]
#  Predicting Sentence [['prohibit', 'sale', 'property', 'sealed', 'bids']]
#
# Sentence 29:
# Predicted class: FailedLords
# Document probabilities: [0.00136077 0.49837784 0.4272025  0.07305889]
# Class probabilities: [0.00136077 0.49837784 0.4272025  0.07305889]
#  Predicting Sentence [['require', 'secretary', 'state', 'publish', 'revised', 'guidance', 'deployment,', 'visibility', 'signing', 'speed', 'red-light', 'cameras', 'traffic', 'enforcement;', 'require', 'guidance', 'include', 'amended', 'site', 'selection', 'criteria', 'safety', 'cameras,', 'including', 'lower', 'threshold', 'number', 'collisions', 'person', 'killed', 'seriously', 'injured;', 'require', 'guidance', 'provide', 'process', 'local', 'communities', 'express', 'support', 'installation', 'safety', 'cameras', 'areas', 'concern']]
#
# Sentence 30:
# Predicted class: SuccessLords
# Document probabilities: [8.12307140e-16 1.32114637e-08 2.33657920e-11 9.99999987e-01]
# Class probabilities: [8.12307140e-16 1.32114637e-08 2.33657920e-11 9.99999987e-01]
#  Predicting Sentence [['require', 'secretary', 'state', 'establish', 'task', 'force', 'produce', 'strategy', 'tackling', 'rural', 'crime;', 'require', 'secretary', 'state', 'implement', 'strategy']]
#
# Sentence 31:
# Predicted class: FailedCommons
# Document probabilities: [9.99999999e-01 1.36851551e-09 7.73610449e-17 2.07475176e-16]
# Class probabilities: [9.99999999e-01 1.36851551e-09 7.73610449e-17 2.07475176e-16]
#  Predicting Sentence [['require', 'public', 'authorities', 'exercise', 'statutory', 'powers', 'investigate', 'take', 'enforcement', 'action', 'breaches', 'law;', 'make', 'provision', 'sanctions', 'failing', 'take', 'action']]
#
# Sentence 32:
# Predicted class: FailedCommons
# Document probabilities: [9.99782648e-01 1.27411298e-11 1.33791989e-07 2.17218580e-04]
# Class probabilities: [9.99782648e-01 1.27411298e-11 1.33791989e-07 2.17218580e-04]
#  Predicting Sentence [['make', 'provision', 'regulation', 'roadworks']]
#
# Sentence 33:
# Predicted class: SuccesCommons
# Document probabilities: [0.06823434 0.37989439 0.38257968 0.16929159]
# Class probabilities: [0.06823434 0.37989439 0.38257968 0.16929159]
#  Predicting Sentence [['require', 'person', 'riding', 'bicycle', 'public', 'highway', 'wear', 'safety', 'helmet']]
#
# Sentence 34:
# Predicted class: SuccesCommons
# Document probabilities: [2.11327331e-04 1.99912664e-01 5.20608809e-01 2.79267200e-01]
# Class probabilities: [2.11327331e-04 1.99912664e-01 5.20608809e-01 2.79267200e-01]
#  Predicting Sentence [['require', 'majesty’s', 'government', 'recognise', 'formally', 'republic', 'somaliland;', 'make', 'provision', 'connection', 'establishing', 'diplomatic', 'relations', 'republic', 'somaliland']]
#
# Sentence 35:
# Predicted class: SuccessLords
# Document probabilities: [8.40588276e-04 5.74717179e-02 4.01823348e-02 9.01505359e-01]
# Class probabilities: [8.40588276e-04 5.74717179e-02 4.01823348e-02 9.01505359e-01]
#  Predicting Sentence [['make', 'provision', 'changing', 'law', 'rented', 'homes,', 'including', 'provision', 'abolishing', 'fixed', 'term', 'assured', 'tenancies', 'assured', 'shorthold', 'tenancies;', 'imposing', 'obligations', 'landlords', 'others', 'relation', 'rented', 'homes', 'temporary', 'supported', 'accommodation']]
#
# Sentence 36:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 1.47639461e-30 2.54778591e-34 3.49571381e-33]
# Class probabilities: [1.00000000e+00 1.47639461e-30 2.54778591e-34 3.49571381e-33]
#  Predicting Sentence [['reduce', 'duty', 'charged', 'renewable', 'liquid', 'heating', 'fuel;', 'provide', 'imposition', 'obligations', 'suppliers', 'heating', 'fuel', 'relation', 'supply', 'renewable', 'fuel']]
#
# Sentence 37:
# Predicted class: SuccessLords
# Document probabilities: [1.12437992e-05 1.84521995e-02 4.20683150e-10 9.81536556e-01]
# Class probabilities: [1.12437992e-05 1.84521995e-02 4.20683150e-10 9.81536556e-01]
#  Predicting Sentence [['give', 'monarch', 'powers', 'remove', 'titles;', 'provide', 'removals', 'done', 'monarch', 'initiative', 'following', 'recommendation', 'joint', 'committee', 'parliament']]
#
# Sentence 38:
# Predicted class: SuccessLords
# Document probabilities: [0.43500026 0.01461849 0.00135363 0.54902762]
# Class probabilities: [0.43500026 0.01461849 0.00135363 0.54902762]
#  Predicting Sentence [['require', 'secretary', 'state', 'report', 'parliament', 'merits', 'house', 'lords', 'meeting', 'large', 'ballroom', 'blackpool']]
#
# Sentence 39:
# Predicted class: SuccessLords
# Document probabilities: [8.82972080e-29 1.94583480e-35 4.89426656e-15 1.00000000e+00]
# Class probabilities: [8.82972080e-29 1.94583480e-35 4.89426656e-15 1.00000000e+00]
#  Predicting Sentence [['make', 'provision', 'require', 'sharing', 'parents', 'guardians', 'copies', 'materials', 'used', 'relationships', 'sex', 'education', 'lessons', 'schools', 'england;', 'prohibit', 'schools', 'england', 'using', 'externally', 'produced', 'teaching', 'resources', 'relationships', 'sex', 'education', 'published']]
#
# Sentence 40:
# Predicted class: FailedCommons
# Document probabilities: [9.90808371e-01 9.19162870e-03 6.79590315e-20 1.29309673e-11]
# Class probabilities: [9.90808371e-01 9.19162870e-03 6.79590315e-20 1.29309673e-11]
#  Predicting Sentence [['require', 'regulatory', 'impact', 'assessment', 'published', 'primary', 'secondary', 'legislation', 'introduced', 'government;', 'make', 'provision', 'associated', 'sanctions']]
#
# Sentence 41:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 2.07846676e-18 6.40754188e-17 1.60407218e-20]
# Class probabilities: [1.00000000e+00 2.07846676e-18 6.40754188e-17 1.60407218e-20]
#  Predicting Sentence [['require', 'local', 'authorities', 'publish', 'register', 'derelict', 'buildings', 'area;', 'make', 'provision', 'respect', 'preparation', 'maintenance', 'registers']]
#
# Sentence 42:
# Predicted class: FailedLords
# Document probabilities: [9.54872469e-10 8.99543788e-01 6.47231596e-02 3.57330510e-02]
# Class probabilities: [9.54872469e-10 8.99543788e-01 6.47231596e-02 3.57330510e-02]
#  Predicting Sentence [['require', 'supermajority', 'votes', 'favour', 'proposal', 'constitutional', 'change', 'referendum', 'held', 'order', 'decided', 'affirmative']]
#
# Sentence 43:
# Predicted class: SuccessLords
# Document probabilities: [0.006473   0.37421138 0.00382226 0.61549337]
# Class probabilities: [0.006473   0.37421138 0.00382226 0.61549337]
#  Predicting Sentence [['require', "majesty's", 'government', 'formally', 'recognise', 'armenian', 'genocide', '1915–23']]
#
# Sentence 44:
# Predicted class: FailedCommons
# Document probabilities: [9.99999989e-01 2.62706915e-09 7.09000195e-09 1.60350759e-09]
# Class probabilities: [9.99999989e-01 2.62706915e-09 7.09000195e-09 1.60350759e-09]
#  Predicting Sentence [['prohibit', 'import', 'young', 'puppies']]
#
# Sentence 45:
# Predicted class: FailedLords
# Document probabilities: [0.00173335 0.91497073 0.0515752  0.03172071]
# Class probabilities: [0.00173335 0.91497073 0.0515752  0.03172071]
#  Predicting Sentence [['create', 'offence', 'impersonating', 'public', 'sector', 'website', 'purpose', 'collecting', 'payment', 'personal', 'data']]
#
# Sentence 46:
# Predicted class: SuccesCommons
# Document probabilities: [1.54380000e-12 1.78414204e-07 9.99999818e-01 3.13277878e-09]
# Class probabilities: [1.54380000e-12 1.78414204e-07 9.99999818e-01 3.13277878e-09]
#  Predicting Sentence [['limit', 'exit', 'payments', 'made', 'public', 'sector', 'organisations', 'employees']]
#
# Sentence 47:
# Predicted class: FailedCommons
# Document probabilities: [9.99998812e-01 1.09678850e-06 1.00150818e-13 9.11016856e-08]
# Class probabilities: [9.99998812e-01 1.09678850e-06 1.00150818e-13 9.11016856e-08]
#  Predicting Sentence [['make', 'provision', 'purpose', 'preventing', 'person', 'failed', 'discharge', 'duty', 'respect', 'child', 'sexual', 'abuse', 'offences', 'holding', 'elected', 'office,', 'holding', 'public', 'office', 'holding', 'post', 'remuneration', 'paid', 'money', 'provided', 'parliament;', 'provide', 'disqualification', 'elected', 'appointed', 'office', 'person', 'convicted', 'child', 'sexual', 'abuse', 'offences;', 'provide', 'removal', 'peerage', 'person', 'convicted', 'child', 'sexual', 'abuse', 'offences']]
#
# Sentence 48:
# Predicted class: SuccesCommons
# Document probabilities: [2.51575159e-14 1.30299040e-17 8.16433580e-01 1.83566420e-01]
# Class probabilities: [2.51575159e-14 1.30299040e-17 8.16433580e-01 1.83566420e-01]
#  Predicting Sentence [['amend', 'public', 'health', '(control', 'disease)', 'act', '1984', 'make', 'provision', 'parliamentary', 'scrutiny', 'regulations', 'made', 'act']]
#
# Sentence 49:
# Predicted class: FailedLords
# Document probabilities: [7.83235927e-42 9.99999311e-01 7.34043332e-11 6.89384717e-07]
# Class probabilities: [7.83235927e-42 9.99999311e-01 7.34043332e-11 6.89384717e-07]
#  Predicting Sentence [['require', 'government', 'regard', 'desirability', 'boards', 'public', 'bodies', 'including', 'least', 'one', 'person', 'relevant', 'experience', 'least', 'one', 'scotland,', 'wales', 'northern', 'ireland']]
#
# Sentence 50:
# Predicted class: FailedCommons
# Document probabilities: [9.99988429e-01 4.77611459e-08 1.15143384e-05 9.11565917e-09]
# Class probabilities: [9.99988429e-01 4.77611459e-08 1.15143384e-05 9.11565917e-09]
#  Predicting Sentence [['establish', 'public', 'advocate', 'provide', 'advice', 'to,', 'act', 'data', 'controller', 'for,', 'representatives', 'deceased', 'major', 'incidents']]
#
# Sentence 51:
# Predicted class: FailedLords
# Document probabilities: [3.76515154e-14 1.00000000e+00 5.07639371e-23 4.31508727e-26]
# Class probabilities: [3.76515154e-14 1.00000000e+00 5.07639371e-23 4.31508727e-26]
#  Predicting Sentence [['make', 'provision', 'carrying', 'functions', 'prime', 'minister', 'event', 'prime', 'minister,', 'person', 'temporarily', 'carrying', 'functions', 'prime', 'minister,', 'incapacitated']]
#
# Sentence 52:
# Predicted class: FailedLords
# Document probabilities: [1.66640830e-09 9.99999998e-01 3.13252704e-18 1.01753624e-15]
# Class probabilities: [1.66640830e-09 9.99999998e-01 3.13252704e-18 1.01753624e-15]
#  Predicting Sentence [['impose', 'duties', 'prime', 'minister', 'relating', 'accountability', 'house', 'commons;', 'require', 'prime', 'minister', 'available', 'answer', 'questions', 'house', 'least', 'two', 'occasions', 'sitting', 'week', 'except', 'specified', 'circumstances']]
#
# Sentence 53:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 1.09769166e-16 3.47090844e-11 1.28126344e-16]
# Class probabilities: [1.00000000e+00 1.09769166e-16 3.47090844e-11 1.28126344e-16]
#  Predicting Sentence [['require', 'secretary', 'state', 'appoint', 'independent', 'reviewer', 'prepare', 'quarterly', 'report', 'containing', 'assessment', 'primary', 'care', 'services;', 'require', 'secretary', 'state', 'lay', 'parliament', 'report', 'prepared', 'independent', 'reviewer;', 'require', 'reports', 'include', 'independent', 'reviewer’s', 'assessment', 'measures', 'taken', 'improve', 'general', 'practice', 'services,', 'dental', 'services,', 'community', 'pharmacy', 'services,', 'optometry', 'services,', 'mental', 'health', 'services']]
#
# Sentence 54:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 7.89171689e-19 6.65198070e-32 2.28255843e-21]
# Class probabilities: [1.00000000e+00 7.89171689e-19 6.65198070e-32 2.28255843e-21]
#  Predicting Sentence [['prohibit', 'installation', 'new', 'pre-payment', 'meters', 'domestic', 'energy', 'customers', '31', 'march', '2023']]
#
# Sentence 55:
# Predicted class: SuccesCommons
# Document probabilities: [4.55400683e-26 6.66380942e-06 9.91457227e-01 8.53610892e-03]
# Class probabilities: [4.55400683e-26 6.66380942e-06 9.91457227e-01 8.53610892e-03]
#  Predicting Sentence [['require', 'energy', 'companies', 'allow', 'grace', 'period', 'disconnecting', 'customers', 'pre-payment', 'meters', 'run', 'credit;', 'require', 'energy', 'companies', 'offer', 'debt', 'management', 'support', 'customers']]
#
# Sentence 56:
# Predicted class: SuccessLords
# Document probabilities: [1.37940199e-09 2.04120004e-09 3.54270926e-02 9.64572904e-01]
# Class probabilities: [1.37940199e-09 2.04120004e-09 3.54270926e-02 9.64572904e-01]
#  Predicting Sentence [['prohibit', 'manufacture', 'sale', 'wet', 'wipes', 'containing', 'plastic']]
#
# Sentence 57:
# Predicted class: SuccessLords
# Document probabilities: [0.04850053 0.08320253 0.11670215 0.7515948 ]
# Class probabilities: [0.04850053 0.08320253 0.11670215 0.7515948 ]
#  Predicting Sentence [['require', 'secretary', 'state', 'publish', 'strategy', 'promoting', 'circular', 'economy', 'respect', 'plastics,', 'including', 'setting', 'targets', 'measures', 'elimination', 'recycling', 'single-use', 'plastics;', 'require', 'secretary', 'state', 'establish', 'taskforce', 'develop', 'proposals', 'encourage', 'use', 'reuse', 'refill', 'models', 'packaging;', 'require', 'secretary', 'state', 'report', 'annually', 'parliament', 'implementation', 'strategy;', 'place', 'duty', 'secretary', 'state', 'ensure', 'uk', 'targets', 'elimination', 'recycling', 'plastic', 'packaging', 'demanding', 'equivalent', 'targets', 'set', 'european', 'union;', 'require', 'manufacturers', 'retailers', 'pay', 'cost', 'recycling', 'plastic;', 'require', 'government', 'set', 'annual', 'targets', 'reducing', 'quantity', 'plastic', 'waste', 'incinerated;', 'require', 'secretary', 'state', 'publish', 'plan', 'banning', 'export', 'plastic', 'waste', '2027;', 'make', 'provision', 'purpose', 'reducing', 'cost', 'recycling', 'plastic,', 'including', 'measures', 'encourage', 'standardisation', 'plastic', 'packaging;', 'give', 'powers', 'office', 'environmental', 'protection', 'enforce', 'legislation', 'relating', 'plastic', 'pollution;', 'make', 'provision', 'purpose', 'encouraging', 'development', 'sustainable', 'alternatives', 'plastic', 'packaging;', 'require', 'government', 'publish', 'plan', 'use', 'fiscal', 'policy', 'incentivise', 'investment', 'recycling', 'infrastructure', 'sustainable', 'behaviour', 'consumers', 'retailers', 'relation', 'plastic;', 'require', 'government', 'publish', 'plan', 'agreeing', 'global', 'treaty', 'plastic', 'pollution', 'reduction']]
#
# Sentence 58:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+000 6.78442808e-077 2.29944109e-147 8.20514694e-089]
# Class probabilities: [1.00000000e+000 6.78442808e-077 2.29944109e-147 8.20514694e-089]
#  Predicting Sentence [['amend', 'town', 'country', 'planning', 'act', '1990', 'enable', 'local', 'authorities', 'england', 'determine', 'fees', 'paid', 'respect', 'applications', 'deemed', 'applications', 'planning', 'permission;', 'require', 'local', 'authorities', 'set', 'scale', 'fees', 'view', 'ensuring', 'costs', 'determining', 'applications', 'wholly', 'funded', 'application', 'fees']]
#
# Sentence 59:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 3.72598673e-12 8.81168661e-12 1.10180676e-15]
# Class probabilities: [1.00000000e+00 3.72598673e-12 8.81168661e-12 1.10180676e-15]
#  Predicting Sentence [['introduce', 'presumption', 'planning', 'decision-making', 'approving', 'quarry', 'development', 'close', 'proximity', 'settlements;', 'require', 'risks', 'proposed', 'quarrying', 'sites', 'environment', 'public', 'health', 'assessed', 'part', 'planning', 'process;', 'provide', 'decision', 'planning', 'application', 'quarry', 'development', 'may', 'made', 'secretary', 'state']]
#
# Sentence 60:
# Predicted class: FailedLords
# Document probabilities: [8.37841214e-23 9.99999688e-01 1.00179499e-24 3.12030317e-07]
# Class probabilities: [8.37841214e-23 9.99999688e-01 1.00179499e-24 3.12030317e-07]
#  Predicting Sentence [['prevent', 'punish', 'theft', 'dogs', 'deter', 'unlawful', 'importation', 'certain', 'animals', 'great', 'britain']]
#
# Sentence 61:
# Predicted class: FailedCommons
# Document probabilities: [9.97393851e-01 2.25022115e-03 1.09182705e-05 3.45009135e-04]
# Class probabilities: [9.97393851e-01 2.25022115e-03 1.09182705e-05 3.45009135e-04]
#  Predicting Sentence [['make', 'provision', 'regarding', 'pets', 'microchips']]
#
# Sentence 62:
# Predicted class: FailedCommons
# Document probabilities: [0.95394853 0.02677498 0.00883398 0.01044251]
# Class probabilities: [0.95394853 0.02677498 0.00883398 0.01044251]
#  Predicting Sentence [['make', 'provision', 'extension', 'pensions', 'automatic', 'enrolment', 'jobholders', 'age', '22;', 'make', 'provision', 'lower', 'qualifying', 'earnings', 'threshold', 'automatic', 'enrolment']]
#
# Sentence 63:
# Predicted class: FailedCommons
# Document probabilities: [9.99586052e-01 1.07208098e-09 4.13947061e-04 1.11810604e-11]
# Class probabilities: [9.99586052e-01 1.07208098e-09 4.13947061e-04 1.11810604e-11]
#  Predicting Sentence [['require', 'employers', 'pay', 'pension', 'contributions', 'pension', 'scheme', 'employee’s', 'choosing']]
#
# Sentence 64:
# Predicted class: FailedCommons
# Document probabilities: [5.26309557e-01 4.00630436e-01 8.29168230e-13 7.30600069e-02]
# Class probabilities: [5.26309557e-01 4.00630436e-01 8.29168230e-13 7.30600069e-02]
#  Predicting Sentence [['extend', 'eligibility', 'paternity', 'leave', 'pay;', 'make', 'provision', 'flexibility', 'timing', 'of,', 'notice', 'period', 'for,', 'paternity', 'leave']]
#
# Sentence 65:
# Predicted class: FailedCommons
# Document probabilities: [9.99949244e-01 1.27702606e-10 6.23706416e-11 5.07560395e-05]
# Class probabilities: [9.99949244e-01 1.27702606e-10 6.23706416e-11 5.07560395e-05]
#  Predicting Sentence [['make', 'provision', 'participating', 'certain', 'court', 'proceedings', 'live', 'links']]
#
# Sentence 66:
# Predicted class: SuccessLords
# Document probabilities: [8.21275618e-05 3.93446640e-03 2.50225310e-04 9.95733181e-01]
# Class probabilities: [8.21275618e-05 3.93446640e-03 2.50225310e-04 9.95733181e-01]
#  Predicting Sentence [['prohibit', 'ministers', 'crown', 'making', 'implementing', 'legal', 'instrument', 'consistent', 'sovereignty', 'united', 'kingdom', 'parliament,', 'unless', 'approved', 'referendum']]
#
# Sentence 67:
# Predicted class: FailedCommons
# Document probabilities: [9.69274191e-01 6.71369875e-14 7.06878842e-03 2.36570205e-02]
# Class probabilities: [9.69274191e-01 6.71369875e-14 7.06878842e-03 2.36570205e-02]
#  Predicting Sentence [['introduce', 'optional', 'preferential', 'voting', 'system', 'parliamentary', 'elections']]
#
# Sentence 68:
# Predicted class: FailedLords
# Document probabilities: [1.64684046e-09 9.99742054e-01 1.09726559e-05 2.46972169e-04]
# Class probabilities: [1.64684046e-09 9.99742054e-01 1.09726559e-05 2.46972169e-04]
#  Predicting Sentence [['grant', 'powers', 'parliamentary', 'health', 'service', 'ombudsman', 'identify', 'investigate', 'systemic', 'problems', 'benefits', 'system', 'make', 'associated', 'recommendations', 'secretary', 'state']]
#
# Sentence 69:
# Predicted class: FailedCommons
# Document probabilities: [9.98700476e-01 1.18814114e-13 2.79424614e-15 1.29952398e-03]
# Class probabilities: [9.98700476e-01 1.18814114e-13 2.79424614e-15 1.29952398e-03]
#  Predicting Sentence [['make', 'provision', 'connection', 'recognition', 'state', 'palestine']]
#
# Sentence 70:
# Predicted class: SuccessLords
# Document probabilities: [1.76147553e-02 5.83474783e-04 1.20332752e-04 9.81681437e-01]
# Class probabilities: [1.76147553e-02 5.83474783e-04 1.20332752e-04 9.81681437e-01]
#  Predicting Sentence [['require', 'every', 'child', 'offered', 'least', 'one', 'outdoor', 'education', 'experience', 'primary', 'school', 'years', 'least', 'one', 'experience', 'secondary', 'school', 'years']]
#
# Sentence 71:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 3.03428335e-22 4.08142169e-56 4.87316258e-27]
# Class probabilities: [1.00000000e+00 3.03428335e-22 4.08142169e-56 4.87316258e-27]
#  Predicting Sentence [['provide', 'secretary', 'state', 'make', 'regulations', 'safety', 'goods', 'sold', 'online']]
#
# Sentence 72:
# Predicted class: FailedLords
# Document probabilities: [8.79529738e-37 9.15802773e-01 1.65073388e-02 6.76898880e-02]
# Class probabilities: [8.79529738e-37 9.15802773e-01 1.65073388e-02 6.76898880e-02]
#  Predicting Sentence [['require', 'social', 'media', 'companies', 'publish', 'reports', 'setting', 'action', 'taken', 'address', 'online', 'abuse', 'women', 'girls,', 'groups', 'people', 'share', 'protected', 'characteristic', 'equality', 'act', '2010']]
#
# Sentence 73:
# Predicted class: FailedCommons
# Document probabilities: [9.99999999e-01 5.50173432e-10 8.41410751e-27 9.49294439e-16]
# Class probabilities: [9.99999999e-01 5.50173432e-10 8.41410751e-27 9.49294439e-16]
#  Predicting Sentence [['require', 'sentencing', 'council', 'issue', 'sentencing', 'guidelines', 'respect', 'sections', '58', '59', 'offences', 'person', 'act', '1861.make', 'provision', 'effect', 'domestic', 'law', 'protocol', 'ireland/northern', 'ireland', 'eu', 'withdrawal', 'agreement,', 'domestic', 'law', 'subject', 'areas', 'dealt', 'protocol', 'connected', 'purposes', 'make', 'provision', 'content', 'use', 'non-disclosure', 'agreements']]
#
# Sentence 74:
# Predicted class: SuccesCommons
# Document probabilities: [5.49307984e-11 2.16176661e-06 9.99997838e-01 4.39414792e-12]
# Class probabilities: [5.49307984e-11 2.16176661e-06 9.99997838e-01 4.39414792e-12]
#  Predicting Sentence [['require', 'community', 'pharmacies', 'providers', 'nhs-funded', 'prescriptions', 'show,', 'patient', 'label,', 'prevailing', 'drug', 'tariff', 'value', 'items', 'dispensed']]
#
# Sentence 75:
# Predicted class: FailedLords
# Document probabilities: [0.02482898 0.7325962  0.14316289 0.09941194]
# Class probabilities: [0.02482898 0.7325962  0.14316289 0.09941194]
#  Predicting Sentence [['make', 'provision', 'arranging', 'alternative', 'non-nhs', 'england', 'treatment', 'patients', 'waited', 'one', 'year', 'hospital', 'treatment']]
#
# Sentence 76:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 2.48472703e-12 5.23978337e-15 6.64349346e-17]
# Class probabilities: [1.00000000e+00 2.48472703e-12 5.23978337e-15 6.64349346e-17]
#  Predicting Sentence [['provide', 'right', 'camp', 'national', 'parks']]
#
# Sentence 77:
# Predicted class: SuccessLords
# Document probabilities: [3.41689209e-02 2.94328232e-01 6.67250864e-04 6.70835597e-01]
# Class probabilities: [3.41689209e-02 2.94328232e-01 6.67250864e-04 6.70835597e-01]
#  Predicting Sentence [['make', 'provision', 'national', 'minimum', 'wage']]
#
# Sentence 78:
# Predicted class: SuccessLords
# Document probabilities: [1.64212366e-04 1.10954275e-06 1.29080865e-01 8.70753813e-01]
# Class probabilities: [1.64212366e-04 1.10954275e-06 1.29080865e-01 8.70753813e-01]
#  Predicting Sentence [['require', 'secretary', 'state', 'report', 'parliament', 'merits', 'extending', '5', 'april', '2025', 'period', 'voluntary', 'class', '2', '3', 'national', 'insurance', 'contributions', 'may', 'paid', 'respect', 'one', 'tax', 'years', '2006-07', '2016-17;', 'require', 'secretary', 'state', 'publish', 'certain', 'information', 'performance', 'future', 'pension', 'centre', 'providing', 'advice', 'voluntary', 'class', '2', '3', 'contributions', 'relation', 'state', 'pension;', 'require', 'secretary', 'state', 'publish', 'strategy', 'increasing', 'public', 'awareness', 'voluntary', 'class', '2', '3', 'contributions']]
#
# Sentence 79:
# Predicted class: SuccessLords
# Document probabilities: [2.02982854e-57 1.37865952e-03 1.34345251e-50 9.98621340e-01]
# Class probabilities: [2.02982854e-57 1.37865952e-03 1.34345251e-50 9.98621340e-01]
#  Predicting Sentence [['make', 'provision', 'co-funding', 'extension', 'co-payment', 'nhs', 'services', 'england']]
#
# Sentence 80:
# Predicted class: FailedCommons
# Document probabilities: [9.99381804e-01 1.15131583e-05 6.00674653e-04 6.00823040e-06]
# Class probabilities: [9.99381804e-01 1.15131583e-05 6.00674653e-04 6.00823040e-06]
#  Predicting Sentence [['require', 'secretary', 'state', 'publish', 'national', 'eye', 'health', 'strategy', 'england;', 'require', 'strategy', 'include', 'measures', 'improving', 'eye', 'health', 'outcomes,', 'reducing', 'waiting', 'times', 'eye', 'health', 'care,', 'improving', 'patient', 'experiences', 'eye', 'health', 'care,', 'ensuring', 'providers', 'eye', 'health', 'care', 'work', 'together', 'efficient', 'way,', 'increasing', 'capacity', 'skills', 'eye', 'health', 'care', 'workforce,', 'making', 'effective', 'use', 'research', 'innovation', 'eye', 'health', 'care']]
#
# Sentence 81:
# Predicted class: FailedLords
# Document probabilities: [4.36283608e-01 5.63716392e-01 4.92255523e-63 2.61410840e-21]
# Class probabilities: [4.36283608e-01 5.63716392e-01 4.92255523e-63 2.61410840e-21]
#  Predicting Sentence [['make', 'provision', 'commemoration', 'nakba;', 'require', 'secretary', 'state', 'encourage', 'facilitate', 'annual', 'commemoration', 'nakba']]
#
# Sentence 82:
# Predicted class: FailedLords
# Document probabilities: [5.98711764e-15 9.79701605e-01 1.15902453e-02 8.70814994e-03]
# Class probabilities: [5.98711764e-15 9.79701605e-01 1.15902453e-02 8.70814994e-03]
#  Predicting Sentence [['increase', 'minimum', 'required', 'height', 'guarding', 'multi-storey', 'car', 'parks;', 'make', 'provision', 'increasing', 'height', 'guarding', 'existing', 'multi-storey', 'car', 'parks;', 'require', '24', 'hour', 'staffing', 'multi-storey', 'car', 'parks']]
#
# Sentence 83:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 1.28774100e-24 2.69810581e-29 1.71399341e-27]
# Class probabilities: [1.00000000e+00 1.28774100e-24 2.69810581e-29 1.71399341e-27]
#  Predicting Sentence [['set', 'standards', 'emissions', 'particulate', 'sensing', 'technology', 'used', 'roadworthiness', 'tests', 'diesel', 'vehicles']]
#
# Sentence 84:
# Predicted class: FailedCommons
# Document probabilities: [9.99999298e-01 6.69459612e-10 2.20080507e-07 4.81310114e-07]
# Class probabilities: [9.99999298e-01 6.69459612e-10 2.20080507e-07 4.81310114e-07]
#  Predicting Sentence [['make', 'provision', 'paid', 'leave', 'people', 'experienced', 'miscarriage']]
#
# Sentence 85:
# Predicted class: FailedLords
# Document probabilities: [6.37332736e-08 9.99906170e-01 5.74493037e-07 9.31919664e-05]
# Class probabilities: [6.37332736e-08 9.99906170e-01 5.74493037e-07 9.31919664e-05]
#  Predicting Sentence [['require', 'minister', 'make', 'oral', 'statement', 'parliament', 'person', 'appointed', 'paid', 'post', 'them,', 'whom,', 'company', 'which,', 'minister', 'personal,', 'political', 'financial', 'interest']]
#
# Sentence 86:
# Predicted class: FailedLords
# Document probabilities: [1.63100243e-20 9.99730194e-01 3.15652249e-07 2.69490748e-04]
# Class probabilities: [1.63100243e-20 9.99730194e-01 3.15652249e-07 2.69490748e-04]
#  Predicting Sentence [['require', 'ministers', 'crown', 'undertake', 'annual', 'training', 'matters', 'relating', 'propriety,', 'ethics', 'standards']]
#
# Sentence 87:
# Predicted class: SuccessLords
# Document probabilities: [1.22530747e-21 3.82645679e-02 4.47017084e-01 5.14718348e-01]
# Class probabilities: [1.22530747e-21 3.82645679e-02 4.47017084e-01 5.14718348e-01]
#  Predicting Sentence [['make', 'provision', 'annual', 'appraisal', 'performance', 'competence', 'individual', 'ministers,', 'conducted', 'outside', 'cabinet', 'office,', 'inform', 'prime', 'minister', 'recommending', 'ministerial', 'appointments']]
#
# Sentence 88:
# Predicted class: FailedLords
# Document probabilities: [4.01591115e-11 9.99602981e-01 2.37537621e-12 3.97018808e-04]
# Class probabilities: [4.01591115e-11 9.99602981e-01 2.37537621e-12 3.97018808e-04]
#  Predicting Sentence [['make', 'provision', 'enforcement', 'ministerial', 'code']]
#
# Sentence 89:
# Predicted class: SuccesCommons
# Document probabilities: [0.00413626 0.20450897 0.70948233 0.08187245]
# Class probabilities: [0.00413626 0.20450897 0.70948233 0.08187245]
#  Predicting Sentence [['provide', 'person', 'ceases', 'hold', 'ministerial', 'office', 'entitled', 'grant', 'holding', 'relevant', 'office', 'two', 'years']]
#
# Sentence 90:
# Predicted class: FailedCommons
# Document probabilities: [9.99999993e-01 6.11466649e-09 1.09909165e-22 7.08174651e-10]
# Class probabilities: [9.99999993e-01 6.11466649e-09 1.09909165e-22 7.08174651e-10]
#  Predicting Sentence [['make', 'provision', 'increase', 'energy', 'performance', 'buildings']]
#
# Sentence 91:
# Predicted class: SuccessLords
# Document probabilities: [1.38790970e-02 4.73299286e-01 1.57503235e-05 5.12805867e-01]
# Class probabilities: [1.38790970e-02 4.73299286e-01 1.57503235e-05 5.12805867e-01]
#  Predicting Sentence [['require', 'manufacturers', 'fit', 'microplastic-catching', 'filters', 'new', 'domestic', 'commercial', 'washing', 'machines;', 'make', 'provision', 'promotion', 'use', 'microplastic-catching', 'filters', 'washing', 'machines', 'raising', 'awareness', 'consequences', 'microplastics', 'washing', 'machines', 'pollution', 'rivers', 'seas']]
#
# Sentence 92:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 4.04507240e-37 8.23952286e-37 1.69736776e-34]
# Class probabilities: [1.00000000e+00 4.04507240e-37 8.23952286e-37 1.69736776e-34]
#  Predicting Sentence [['require', 'leader', 'house', 'commons', 'move', 'motion', 'prohibiting', 'members', 'parliament', 'receiving', 'financial', 'benefit', 'oil', 'gas', 'companies;', 'require', 'leader', 'house', 'publish', 'proposals', 'divestment', 'parliamentary', 'contributory', 'pension', 'fund', 'oil', 'gas', 'companies']]
#
# Sentence 93:
# Predicted class: SuccessLords
# Document probabilities: [8.39743021e-66 1.13271128e-17 1.71643544e-44 1.00000000e+00]
# Class probabilities: [8.39743021e-66 1.13271128e-17 1.71643544e-44 1.00000000e+00]
#  Predicting Sentence [['require', 'secretary', 'state', 'undertake', 'review', 'support', 'available', 'markets', 'market', 'traders', 'options', 'improving', 'support']]
#
# Sentence 94:
# Predicted class: SuccessLords
# Document probabilities: [3.17006459e-06 2.55944879e-05 1.25945320e-01 8.74025915e-01]
# Class probabilities: [3.17006459e-06 2.55944879e-05 1.25945320e-01 8.74025915e-01]
#  Predicting Sentence [['transfer', 'responsibility', 'marine', 'licensing', 'marine', 'management', 'organisation', 'local', 'authorities']]
#
# Sentence 95:
# Predicted class: SuccessLords
# Document probabilities: [2.39689316e-15 2.05401191e-05 1.04846186e-09 9.99979459e-01]
# Class probabilities: [2.39689316e-15 2.05401191e-05 1.04846186e-09 9.99979459e-01]
#  Predicting Sentence [['require', 'secretary', 'state', 'establish', 'export', 'guarantee', 'scheme', 'small', 'generators', 'low', 'carbon', 'electricity;', 'set', 'tariff,', 'based', 'market', 'rates,', 'sale', 'electricity', 'export', 'guarantee', 'scheme;', 'make', 'provision', 'enable', 'small', 'generators', 'low', 'carbon', 'electricity', 'sell', 'electricity', 'directly', 'local', 'people;', 'place', 'certain', 'duties', 'gas', 'electricity', 'markets', 'authority']]
#
# Sentence 96:
# Predicted class: FailedCommons
# Document probabilities: [1.00000000e+00 6.16032621e-25 1.02412062e-26 2.07951777e-19]
# Class probabilities: [1.00000000e+00 6.16032621e-25 1.02412062e-26 2.07951777e-19]
#  Predicting Sentence [['enable', 'electricity', 'generators', 'become', 'local', 'electricity', 'suppliers']]
#
# Sentence 97:
# Predicted class: FailedCommons
# Document probabilities: [9.99999999e-01 2.81774688e-10 3.18717671e-11 7.41371415e-10]
# Class probabilities: [9.99999999e-01 2.81774688e-10 3.18717671e-11 7.41371415e-10]
#  Predicting Sentence [['make', 'provision', 'enable', 'parliamentary', 'constituency', 'areas', 'form', 'new', 'unitary', 'local', 'authority', 'areas', 'agreed', 'referendum;', 'make', 'provision', 'referendums']]
#
# Sentence 98:
# Predicted class: FailedLords
# Document probabilities: [1.98926629e-03 9.97114426e-01 5.20839815e-10 8.96306829e-04]
# Class probabilities: [1.98926629e-03 9.97114426e-01 5.20839815e-10 8.96306829e-04]
#  Predicting Sentence [['make', 'provision', 'changing', 'local', 'authority', 'boundaries', 'cases', 'public', 'support', 'changes']]
#
# Sentence 99:
# Predicted class: SuccesCommons
# Document probabilities: [2.00266046e-31 3.37290619e-02 9.60958590e-01 5.31234814e-03]
# Class probabilities: [2.00266046e-31 3.37290619e-02 9.60958590e-01 5.31234814e-03]
#  Predicting Sentence [['make', 'local', 'fire', 'services', 'statutory', 'consultees', 'industrial', 'lithium-ion', 'battery', 'storage', 'planning', 'permission', 'applications;', 'make', 'provision', 'granting', 'environmental', 'permits', 'industrial', 'lithium-ion', 'battery', 'storage']]
#
# Sentence 100:
# Predicted class: FailedLords
# Document probabilities: [2.30764665e-01 7.64997992e-01 1.02988442e-20 4.23734363e-03]
# Class probabilities: [2.30764665e-01 7.64997992e-01 1.02988442e-20 4.23734363e-03]
#  Predicting Sentence [['provide', 'statutory', 'definition', 'kinship', 'care;', 'make', 'provision', 'allowances', 'parental', 'leave', 'kinship', 'carers', 'take', 'responsibility', 'children', 'whose', 'parents', 'unable', 'care', 'them;', 'make', 'provision', 'education', 'relation', 'children', 'looked', 'kinship', 'carer']]
#
# Sentence 101:
# Predicted class: FailedLords
# Document probabilities: [3.04740136e-02 9.69515189e-01 1.02971273e-05 5.00244489e-07]
# Class probabilities: [3.04740136e-02 9.69515189e-01 1.02971273e-05 5.00244489e-07]
#  Predicting Sentence [['place', 'duty', 'secretary', 'state', 'ensure', 'children', 'eligible', 'free', 'school', 'meals', 'broadband', 'connection', 'facilities', 'access', 'internet', 'home']]
#
# Sentence 102:
# Predicted class: FailedLords
# Document probabilities: [2.61085616e-12 9.97711727e-01 5.41598463e-08 2.28821904e-03]
# Class probabilities: [2.61085616e-12 9.97711727e-01 5.41598463e-08 2.28821904e-03]
#  Predicting Sentence [['require', 'prime', 'minister', 'appoint', 'special', 'envoy', 'international', 'freedom', 'religion', 'belief;', 'establish', 'office', 'special', 'envoy']]
#
# Sentence 103:
# Predicted class: FailedLords
# Document probabilities: [2.52266132e-21 9.79552716e-01 2.79879022e-05 2.04192961e-02]
# Class probabilities: [2.52266132e-21 9.79552716e-01 2.79879022e-05 2.04192961e-02]
#  Predicting Sentence [['prohibit', 'public', 'bodies', 'spending', 'legal', 'representation', 'inquest', 'amount', 'spent', 'families', 'deceased;', 'require', 'secretary', 'state', 'report', 'parliament', 'availability', 'accessibility', 'legal', 'representation', 'families', 'inquests']]
#
# Sentence 104:
# Predicted class: FailedLords
# Document probabilities: [2.45929903e-01 7.54070095e-01 2.24563631e-16 2.70015680e-09]
# Class probabilities: [2.45929903e-01 7.54070095e-01 2.24563631e-16 2.70015680e-09]
#  Predicting Sentence [['make', 'provision', 'appointment', 'parliament', 'independent', 'anti-slavery', 'commissioner', 'post', 'vacant', 'three', 'months']]
#
# Sentence 105:
# Predicted class: FailedLords
# Document probabilities: [1.96810992e-23 9.40089489e-01 2.17742093e-05 5.98887372e-02]
# Class probabilities: [1.96810992e-23 9.40089489e-01 2.17742093e-05 5.98887372e-02]
#  Predicting Sentence [['make', 'provision', 'appointment', 'parliament', 'independent', 'adviser', 'ministers’', 'interests']]
#
# Sentence 106:
# Predicted class: FailedLords
# Document probabilities: [5.75408606e-08 5.57927813e-01 9.73283367e-04 4.41098846e-01]
# Class probabilities: [5.75408606e-08 5.57927813e-01 9.73283367e-04 4.41098846e-01]
#  Predicting Sentence [['prohibit', 'import', 'puppies', 'six', 'months;', 'prohibit', 'import', 'pregnant', 'dogs', 'specified', 'circumstances;', 'prohibit', 'import', 'dogs', 'cropped', 'ears', 'docked', 'tails']]
#
# Sentence 107:
# Predicted class: FailedLords
# Document probabilities: [6.01106844e-13 9.99993559e-01 2.55243973e-07 6.18580424e-06]
# Class probabilities: [6.01106844e-13 9.99993559e-01 2.55243973e-07 6.18580424e-06]
#  Predicting Sentence [['exempt', 'nhs', 'clinical', 'staff', 'requirement', 'pay', 'fees', 'section', '68', 'immigration', 'act', '2014']]
#
# Sentence 108:
# Predicted class: SuccessLords
# Document probabilities: [2.67399457e-07 1.05823821e-02 1.11864923e-03 9.88298701e-01]
# Class probabilities: [2.67399457e-07 1.05823821e-02 1.11864923e-03 9.88298701e-01]
#  Predicting Sentence [['create', 'offences', 'respect', 'persons', 'entered', 'uk', 'illegally', 'remained', 'uk', 'without', 'legal', 'authority']]
#
# Sentence 109:
# Predicted class: FailedCommons
# Document probabilities: [9.62677080e-01 3.73228535e-02 9.49986235e-14 6.61105334e-08]
# ...
#  Predicting Sentence [['implement,', 'make', 'provision', 'connection', 'with,', 'trade', 'cooperation', 'agreement;', 'make', 'provision', 'connection', 'united', 'kingdom’s', 'future', 'relationship', 'eu', 'member', 'states;', 'make', 'related', 'provision', 'passenger', 'name', 'record', 'data,', 'customs', 'privileges', 'immunities']]
#
# Sentence 179:
# Predicted class: SuccesCommons
# Document probabilities: [1.03472764e-40 7.68929184e-32 1.00000000e+00 9.20707766e-12]
# Class probabilities: [1.03472764e-40 7.68929184e-32 1.00000000e+00 9.20707766e-12]
#  Predicting Sentence [['make', 'provision', 'targets,', 'plans', 'policies', 'improving', 'natural', 'environment;', 'statements', 'reports', 'environmental', 'protection;', 'office', 'environmental', 'protection;', 'waste', 'resource', 'efficiency;', 'air', 'quality;', 'recall', 'products', 'fail', 'meet', 'environmental', 'standards;', 'water;', 'nature', 'biodiversity;', 'conservation', 'covenants;']]
#
# Sentence 180:
# Predicted class: SuccesCommons
# Document probabilities: [5.10364393e-12 1.19449085e-28 1.00000000e+00 6.96069217e-24]
# Class probabilities: [5.10364393e-12 1.19449085e-28 1.00000000e+00 6.96069217e-24]
#  Predicting Sentence []
#
# Sentence 181:
# Predicted class: FailedCommons
# Document probabilities: [nan nan nan nan]
# Class probabilities: [nan nan nan nan]
#  Predicting Sentence [['regulation', 'chemicals']]
#
# Sentence 182:
# Predicted class: FailedCommons
# Document probabilities: [0.25 0.25 0.25 0.25]
# Class probabilities: [0.25 0.25 0.25 0.25]
#  Predicting Sentence [['impose', 'duties', 'certain', 'education', 'training', 'providers', 'relation', 'safeguarding', 'promoting', 'welfare', 'children']]
#
# Sentence 183:
# Predicted class: FailedLords
# Document probabilities: [4.00636742e-46 1.00000000e+00 4.60836745e-13 1.37655357e-14]
# Class probabilities: [4.00636742e-46 1.00000000e+00 4.60836745e-13 1.37655357e-14]
#  Predicting Sentence [['make', 'provision', 'guidance', 'schools', 'costs', 'aspects', 'school', 'uniform', 'policies.to', 'make', 'provision', 'relation', 'domestic', 'abuse;', 'make', 'provision', 'connection', 'establishment', 'domestic', 'abuse', 'commissioner;', 'prohibit', 'cross-examination', 'person', 'family', 'proceedings', 'certain', 'circumstances;', 'make', 'provision', 'certain', 'violent', 'sexual', 'offences,', 'offences', 'involving']]
#
# Sentence 184:
# Predicted class: SuccessLords
# Document probabilities: [4.98705102e-06 3.34079726e-11 7.78729540e-02 9.22122059e-01]
# Class probabilities: [4.98705102e-06 3.34079726e-11 7.78729540e-02 9.22122059e-01]
#  Predicting Sentence []
#
# Sentence 185:
# Predicted class: FailedCommons
# Document probabilities: [nan nan nan nan]
# Class probabilities: [nan nan nan nan]
#  Predicting Sentence [['abusive', 'behaviour,', 'committed', 'outside', 'united', 'kingdom.to', 'make', 'provision', 'incorporation', 'direct', 'payments', 'regulation', 'domestic', 'law;', 'enabling', 'increase', 'total', 'maximum', 'amount', 'direct', 'payments', 'regulation']]
#
# Sentence 186:
# Predicted class: SuccesCommons
# Document probabilities: [3.44830132e-51 2.65098264e-13 1.00000000e+00 3.61517700e-11]
# Class probabilities: [3.44830132e-51 2.65098264e-13 1.00000000e+00 3.61517700e-11]
#  Predicting Sentence [['make', 'provision', 'for,', 'connection', 'with,', 'authorisation', 'criminal', 'conduct', 'course', 'of,', 'otherwise', 'connection', 'with,', 'conduct', 'covert', 'human', 'intelligence', 'sources']]
#
# Sentence 187:
# Predicted class: SuccesCommons
# Document probabilities: [1.50441317e-72 2.41064593e-31 1.00000000e+00 1.44408210e-16]
# Class probabilities: [1.50441317e-72 2.41064593e-31 1.00000000e+00 1.44408210e-16]
#  Predicting Sentence [['make', 'provision', 'sentencing', 'offenders', 'convicted', 'terrorism', 'offences,', 'offences', 'terrorist', 'connection', 'certain', 'offences;', 'make', 'provision', 'relation', 'terrorism']]
#
# Sentence 188:
# Predicted class: SuccesCommons
# Document probabilities: [9.84087883e-13 2.82715830e-29 1.00000000e+00 6.19446020e-11]
# Class probabilities: [9.84087883e-13 2.82715830e-29 1.00000000e+00 6.19446020e-11]
#  Predicting Sentence [['make', 'provision', 'companies', 'entities', 'financial', 'difficulty;', 'make', 'temporary', 'changes', 'law', 'relating', 'governance', 'regulation', 'companies', 'entities']]
#
# Sentence 189:
# Predicted class: SuccesCommons
# Document probabilities: [1.30852748e-40 1.26794676e-19 1.00000000e+00 1.96074649e-10]
# Class probabilities: [1.30852748e-40 1.26794676e-19 1.00000000e+00 1.96074649e-10]
#  Predicting Sentence [['make', 'provision', 'connection', 'coronavirus']]
#
# Sentence 190:
# Predicted class: SuccesCommons
# Document probabilities: [0.13359543 0.05803635 0.44883457 0.35953365]
# Class probabilities: [0.13359543 0.05803635 0.44883457 0.35953365]
#  Predicting Sentence [['make', 'provision', 'increasing', 'maximum', 'capital', 'contingencies', 'fund']]
#
# Sentence 191:
# Predicted class: FailedCommons
# Document probabilities: [9.64703175e-01 3.86032795e-03 1.22320364e-09 3.14364962e-02]
# Class probabilities: [9.64703175e-01 3.86032795e-03 1.22320364e-09 3.14364962e-02]
#  Predicting Sentence []
#
# Sentence 192:
# Predicted class: FailedCommons
# Document probabilities: [nan nan nan nan]
# Class probabilities: [nan nan nan nan]
#  Predicting Sentence [['temporary', 'period']]
#
# Sentence 193:
# Predicted class: SuccesCommons
# Document probabilities: [0.32459454 0.17528032 0.34648919 0.15363595]
# Class probabilities: [0.32459454 0.17528032 0.34648919 0.15363595]
#  Predicting Sentence [['make', 'provision', 'increasing', 'maximum', 'capital', 'contingencies', 'fund', 'temporary', 'period']]
#
# Sentence 194:
# Predicted class: SuccessLords
# Document probabilities: [3.57576453e-01 4.11810655e-02 3.23379088e-06 6.01239248e-01]
# Class probabilities: [3.57576453e-01 4.11810655e-02 3.23379088e-06 6.01239248e-01]
#  Predicting Sentence [['make', 'provision', 'relating', 'promotion', 'economic', 'recovery', 'growth']]
#
# Sentence 195:
# Predicted class: FailedLords
# Document probabilities: [7.80944282e-08 5.89715879e-01 1.63570880e-02 3.93926955e-01]
# Class probabilities: [7.80944282e-08 5.89715879e-01 1.63570880e-02 3.93926955e-01]
#  Predicting Sentence [['provide', 'british', 'library', 'board', 'power', 'borrow', 'money']]
#
# Sentence 196:
# Predicted class: SuccessLords
# Document probabilities: [6.23487564e-05 2.34911922e-03 1.91742389e-01 8.05846143e-01]
# Class probabilities: [6.23487564e-05 2.34911922e-03 1.91742389e-01 8.05846143e-01]
#  Predicting Sentence [['make', 'provision', 'administration', 'persons', 'age', '18', 'botulinum', 'toxin', 'substances', 'cosmetic', 'purposes']]
#
# Sentence 197:
# Predicted class: SuccesCommons
# Document probabilities: [8.72999810e-08 1.51378419e-09 9.99999791e-01 1.19743695e-07]
# Class probabilities: [8.72999810e-08 1.51378419e-09 9.99999791e-01 1.19743695e-07]
#  Predicting Sentence [['continue', 'armed', 'forces', 'act', '2006;', 'amend', 'act', 'enactments', 'relating', 'armed', 'forces;', 'make', 'provision', 'service', 'reserve', 'forces;', 'make', 'provision', 'pardons', 'certain', 'abolished', 'service', 'offences;', 'make', 'provision', 'war', 'pensions']]
#
# Sentence 198:
# Predicted class: SuccesCommons
# Document probabilities: [1.46109395e-80 4.33046399e-24 1.00000000e+00 1.33866930e-25]
# Class probabilities: [1.46109395e-80 4.33046399e-24 1.00000000e+00 1.33866930e-25]
#  Predicting Sentence [['make', 'provision', 'mode', 'trial', 'maximum', 'penalty', 'certain', 'offences', 'animal', 'welfare', 'act', '2006.nan', 'make', 'provision', 'connection', 'establishment', 'advanced']]
#
# Sentence 199:
# Predicted class: SuccessLords
# Document probabilities: [2.50880295e-16 1.96158926e-03 1.90832317e-06 9.98036502e-01]
# Class probabilities: [2.50880295e-16 1.96158926e-03 1.90832317e-06 9.98036502e-01]
#  Predicting Sentence []
#
# Sentence 200:
# Predicted class: FailedCommons
# Document probabilities: [nan nan nan nan]
# Class probabilities: [nan nan nan nan]
#  Predicting Sentence [['research', 'invention', 'agency.']]
#
# Sentence 201:
# Predicted class: FailedCommons
# Document probabilities: [0.25 0.25 0.25 0.25]
# Class probabilities: [0.25 0.25 0.25 0.25]
# Correct Prediction: 0.5223880597014925
#  Number of sentences for SuccessLords is 8
# The accuracy for SuccessLords is
#  Predicting Sentence [['make', 'provision', 'uk', 'infrastructure', 'bank', 'provide', 'certain', 'social', 'security', 'rules', 'apply', 'life', 'expectancy', '6', 'months', 'less', 'apply', 'instead', 'life', 'expectancy', '12', 'months', 'less', 'make', 'provision', 'regulation', 'social', 'housing;', 'terms', 'approved', 'schemes', 'investigation', 'housing', 'complaints']]
#
# Sentence 1:
# Predicted class: SuccessLords
# Document probabilities: [2.90964420e-87 5.36250322e-44 4.20133131e-29 1.00000000e+00]
# Class probabilities: [2.90964420e-87 5.36250322e-44 4.20133131e-29 1.00000000e+00]
#  Predicting Sentence [['make', 'provision', 'relation', 'remuneration', 'seafarers', 'qualify', 'national', 'minimum', 'wage', 'make', 'provision', 'procurement', 'make', 'provision', 'national', 'cultural', 'identity', 'language', 'northern', 'ireland', 'make', 'provision', 'energy', 'production', 'security', 'regulation', 'energy', 'market,', 'including', 'provision', 'licensing', 'carbon', 'dioxide', 'transport', 'storage;', 'commercial', 'arrangements', 'carbon', 'capture', 'storage', 'hydrogen', 'production', 'transportation;', 'new', 'technology,', 'including', 'low-carbon', 'heat', 'schemes', 'hydrogen', 'grid', 'trials;', 'independent', 'system', 'operator', 'planner;', 'gas', 'electricity', 'industry', 'codes;', 'financial', 'support', 'persons', 'carrying', 'energy-intensive', 'activities;', 'heat', 'networks;', 'energy', 'smart', 'appliances', 'load', 'control;', 'energy', 'performance', 'premises;', 'energy', 'savings', 'opportunity', 'schemes;', 'resilience', 'core', 'fuel', 'sector;', 'offshore', 'energy', 'production,', 'including', 'environmental', 'protection,', 'licensing', 'decommissioning;', 'civil', 'nuclear', 'sector,', 'including', 'civil', 'nuclear', 'constabulary', 'pensions']]
#
# Sentence 2:
# Predicted class: SuccessLords
# Document probabilities: [2.13260188e-146 1.34749434e-085 3.13543895e-064 1.00000000e+000]
# Class probabilities: [2.13260188e-146 1.34749434e-085 3.13543895e-064 1.00000000e+000]
#  Predicting Sentence [['make', 'provision', 'electronic', 'trade', 'documents']]
#
# Sentence 3:
# Predicted class: FailedLords
# Document probabilities: [4.78368017e-05 9.61947881e-01 3.42387685e-02 3.76551346e-03]
# Class probabilities: [4.78368017e-05 9.61947881e-01 3.42387685e-02 3.76551346e-03]
#  Predicting Sentence [['add', 'royal', 'highness', 'earl', 'wessex', 'royal', 'highness', 'princess', 'royal', 'persons', 'royal', 'functions', 'may', 'delegated', 'counsellors', 'state']]
#
# Sentence 4:
# Predicted class: FailedLords
# Document probabilities: [1.19262593e-14 6.24853049e-01 1.60472517e-02 3.59099699e-01]
# Class probabilities: [1.19262593e-14 6.24853049e-01 1.60472517e-02 3.59099699e-01]
#  Predicting Sentence [['confer', 'powers', 'upon', "bishop's", 'stortford', 'town', 'council', 'extinguish', 'rights', 'burial', 'disturb', 'human', 'remains', 'bishop', "stortford's", 'new', 'cemetery', 'old', 'cemetery', 'purpose', 'increasing', 'space', 'interments']]
#
# Sentence 5:
# Predicted class: SuccessLords
# Document probabilities: [8.92406880e-44 2.08319718e-35 2.16303757e-33 1.00000000e+00]
# Class probabilities: [8.92406880e-44 2.08319718e-35 2.16303757e-33 1.00000000e+00]
#  Predicting Sentence [['make', 'provision', 'ensuring', 'secrecy', 'ballots', 'cast', 'polling', 'stations', 'elections', 'make', 'provision', 'local', 'skills', 'improvement', 'plans;', 'make', 'provision', 'relating', 'education;', 'make', 'provision', 'functions', 'institute', 'apprenticeships', 'technical', 'education', 'relating', 'technical', 'education', 'qualifications;', 'make', 'provision', 'student', 'finance', 'fees;', 'make', 'provision', 'assessments', 'office', 'students;', 'make', 'provision', 'funding', 'certain', 'post-16', 'education', 'training', 'providers', 'make', 'provision', 'public', 'service', 'pension', 'schemes,', 'including', 'retrospective', 'provision', 'rectify', 'unlawful', 'discrimination', 'way', 'existing', 'schemes', 'restricted', 'public', 'service', 'pensions', 'act', '2013', 'corresponding', 'northern', 'ireland', 'legislation;', 'make', 'provision', 'establishment', 'new', 'public', 'pension', 'schemes', 'members', 'occupational', 'pension', 'schemes', 'bodies', 'brought', 'public', 'ownership', 'banking', '(special', 'provisions)', 'act', '2008;', 'make', 'provision', 'remuneration', 'date', 'retirement', 'holders', 'certain', 'judicial', 'offices;', 'make', 'provision', 'judicial', 'service', 'retirement', 'make', 'provision', 'relating', 'entitlement', 'practise', 'certain', 'professions,', 'occupations', 'trades', 'make', 'provision', 'rent', 'payable', 'long', 'leases', 'dwellings', 'make', 'provision', 'connection', 'expanded', 'dormant', 'assets', 'scheme;', 'confer', 'power', 'expand', 'scope', 'scheme;', 'amend', 'dormant', 'bank', 'building', 'society', 'accounts', 'act', '2008;', 'enable', 'authorised', 'reclaim', 'fund', 'accept', 'transfers', 'certain', 'unwanted', 'assets', 'make', 'provision', 'meaning', 'references', 'article', '23a', 'benchmarks', 'contracts', 'arrangements;', 'make', 'provision', 'liability', 'administrators', 'article', '23a', 'benchmarks', 'amend', 'charities', 'act', '2011', 'universities', 'college', 'estates', 'act', '1925', 'make', 'provision', 'animal', 'sentience', 'committee', 'functions', 'relating', 'effect', 'government', 'policy', 'welfare', 'animals', 'sentient', 'beings', 'give', 'effect', 'law', 'commission', 'recommendations', 'relating', 'commencement', 'enactments', 'relating', 'sentencing', 'law', 'make', 'provision', 'pre-consolidation', 'amendments', 'sentencing', 'law', 'consolidate', 'certain', 'enactments', 'relating', 'sentencing']]
#
# Sentence 6:
# Predicted class: SuccessLords
# Document probabilities: [0.00000000e+00 5.58462741e-81 2.17406728e-94 1.00000000e+00]
# Class probabilities: [0.00000000e+00 5.58462741e-81 2.17406728e-94 1.00000000e+00]
#  Predicting Sentence [['implement', 'hague', 'conventions', '1996,', '2005', '2007', 'provide', 'implementation', 'international', 'agreements', 'private', 'international', 'law']]
#
# Sentence 7:
# Predicted class: SuccessLords
# Document probabilities: [6.52875115e-27 1.72905788e-02 1.75793272e-09 9.82709419e-01]
# Class probabilities: [6.52875115e-27 1.72905788e-02 1.75793272e-09 9.82709419e-01]
#  Predicting Sentence [['make', 'provision', 'pension', 'schemes', 'make', 'provision', 'relation', 'fisheries,', 'fishing,', 'aquaculture', 'marine', 'conservation;', 'make', 'provision', 'functions', 'marine', 'management', 'organisation', 'create', 'power', 'arrest,', 'without', 'warrant,', 'purpose', 'extraditing', 'people', 'serious', 'offences', 'make', 'relation', 'marriage', 'civil', 'partnership', 'england', 'wales', 'provision', 'divorce,', 'dissolution', 'separation', 'make', 'provision', 'commonwealth', 'games', 'held', 'principally', 'birmingham', '2022', 'make', 'provision', 'airspace', 'change', 'proposals', 'licensing', 'regime', 'air', 'traffic', 'services', 'part', '1', 'transport', 'act', '2000,', 'confer', 'police', 'powers', 'relating', 'unmanned', 'aircraft', 'requirements', 'air', 'navigation', 'orders', 'provide', 'fixed', 'penalties', 'certain', 'offences', 'relating', 'unmanned', 'aircraft']]
#
# Sentence 8:
# Predicted class: SuccessLords
# Document probabilities: [1.53238263e-179 3.72576847e-064 1.85821078e-037 1.00000000e+000]
# Class probabilities: [1.53238263e-179 3.72576847e-064 1.85821078e-037 1.00000000e+000]
# Correct Prediction: 0.75
# Model for FailedCommons saved as FailedCommons_word2vec_titles.model
# Model for FailedLords saved as FailedLords_word2vec_titles.model
# Model for SuccesCommons saved as SuccesCommons_word2vec_titles.model
# Model for SuccessLords saved as SuccessLords_word2vec_titles.model

# %%
def splitIntoSets(code):
    csv_path = f"C:\\Users\\ander\\Downloads\\MLP\\CSVFilesWithTitleScores\\{code}_17 to 39_withTitleScores.csv"

    df = pd.read_csv(csv_path)

    total_rows = len(df)
    testingSetSize = round(0.1 * total_rows)
    remainingSize = total_rows - testingSetSize


    testingSet = df.iloc[:testingSetSize]['Bill Id'].tolist()


    remaining_df = df.iloc[testingSetSize:].sample(frac=1, random_state=42) 
    
    validationSet = remaining_df.iloc[:testingSetSize]['Bill Id'].tolist()


    trainingSet = remaining_df.iloc[testingSetSize:]['Bill Id'].tolist()
    
    return trainingSet, testingSet, validationSet

remaining = [28, 29, 18, 19]

for code in remaining :
    trainingIndexes, testingIndexes, validationIndexes = splitIntoSets(code)
    df = pd.read_csv(f"C:\\Users\\ander\\Downloads\\MLP\\CSVFilesWithTitleScores\\{code}_17 to 39_withTitleScores.csv")


    df_training = df[df['Bill Id'].isin(trainingIndexes)]
    df_testing = df[df['Bill Id'].isin(testingIndexes)]
    df_validation = df[df['Bill Id'].isin(validationIndexes)]
    df_training.to_csv(f"C:\\Users\\ander\\Downloads\\MLP\\CSVFilesWithTitleScores\\{code}\\Training\\{code}_training.csv", index=False)
    df_testing.to_csv(f"C:\\Users\\ander\\Downloads\\MLP\\CSVFilesWithTitleScores\\{code}\\Testing\\{code}_testing.csv", index=False)
    df_validation.to_csv(f"C:\\Users\\ander\\Downloads\\MLP\\CSVFilesWithTitleScores\\{code}\\Validation\\{code}_validation.csv", index=False)
